# %%
from PIL import Image

# %%
Logo = 'python-logo.png'

# %%
Image.open(Logo)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=136x163>

# %%
Image.open(Logo, formats = ('png', 'jpg'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=136x163>

# %%
Image.open('Physarum polycephalum.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=563x462>

# %%
Image.open('Physarum polycephalum.png').rotate(-75.4568)
# Out:
# <PIL.Image.Image image mode=RGBA size=563x462>

# %%
Image.open('Physarum polycephalum.png').rotate(75.4568).save("NewImage.png")

# %%
Astr = 'astronaut.png'

# %%
Image.open(Astr)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=LA size=4167x4167>

# %%
Image.open(Astr).rotate(45)

# %%
for i in range(37):
    Image.open(Astr).rotate(i*10).save(f"AStro{i*10}.png")

# %%
360/10
# Out:
# 36.0
